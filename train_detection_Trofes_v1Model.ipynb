# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Perintah ini akan mengekstrak file ZIP dari Drive ke folder Colab
# !unzip -q "/content/drive/MyDrive/Trofes_Detection_dataset3.v4-tes-4.yolov8.zip" -d /content/dataset

# %%
import yaml

# Perbaiki path di data.yaml agar sesuai dengan lokasi folder /content/dataset
yaml_path = '/content/dataset/data.yaml'
with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

config['path'] = '/content/dataset'  # Folder utama dataset
config['train'] = 'train/images'
config['val'] = 'valid/images'
config['test'] = 'test/images'

with open(yaml_path, 'w') as f:
    yaml.dump(config, f)

print("data.yaml berhasil diperbaiki!")
# Out:
# data.yaml berhasil diperbaiki!

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    project='/content/drive/MyDrive/Trofes_Project',
    name='yolov8m_Detection_colab',
    cache=False,
    workers=8,
    patience=15,
    save_period=5,
    exist_ok=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Sesuaikan path dengan folder project kamu di Drive
path = '/content/drive/MyDrive/Trofes_Project/yolov8m_Detection_colab/results.csv'

try:
    img = mpimg.imread(path)
    plt.figure(figsize=(20, 15)) # Ukuran besar agar detail terlihat
    plt.imshow(img)
    plt.axis('off')
    plt.title('Update Grafik Training Trofes (Hingga Epoch Terakhir)')
    plt.show()
except:
    print("File belum tersedia atau path salah. Cek folder di Drive kamu ya!")

# %%
# !pip install ultralytics

# %%
# 1. Mount Drive & Install Library
from google.colab import drive
from ultralytics import YOLO
import os

drive.mount('/content/drive')


# 2. Persiapan Folder & Ekstrak Dataset (Nama File yang Benar)
# Menggunakan nama file dari gambar yang kamu kirim tadi
dataset_zip = "/content/drive/MyDrive/Trofes_Detection_dataset3.v4-tes-4.yolov8.zip"
target_folder = "/content/dataset"

if not os.path.exists(target_folder):
    os.makedirs(target_folder)
    # Pastikan nama file ZIP di bawah ini sesuai dengan yang ada di Drive-mu
    # !unzip -q "{dataset_zip}" -d {target_folder}

    # Cek apakah unzip berhasil
    if os.path.exists(f"{target_folder}/data.yaml"):
        print("BERHASIL! Dataset dan data.yaml sudah siap di akun kedua.")
    else:
        print("GAGAL! File ZIP tidak ditemukan atau nama file salah.")
        print("Daftar file di Drive-mu:", os.listdir('/content/drive/MyDrive/'))
else:
    print("ℹ Folder dataset sudah ada, tidak perlu unzip ulang.")

# 3. Resume Training dari Titik Terakhir (Epoch 9)
# Pastikan path folder project ini sudah benar di Drive akun kedua
path_last = '/content/drive/MyDrive/Trofes_Project/yolov8m_Detection_colab/weights/last.pt'

if os.path.exists(path_last):
    print("Menghubungkan ke 'last.pt',Melanjutkan training Trofes!")
    model = YOLO(path_last)
    # resume=True akan otomatis mencari data.yaml yang baru saja di-unzip
    model.train(resume=True)
else:
    print("ERROR: File 'last.pt' tidak ditemukan!")
    print("Pastikan folder 'Trofes_Project' sudah di-share sebagai Editor dan di-Add Shortcut.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ℹ Folder dataset sudah ada, tidak perlu unzip ulang.
# Menghubungkan ke 'last.pt',Melanjutkan training Trofes!
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #Training Dataset Baru

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -rf /content/drive/MyDrive/Trofes_Project/yolov8m_Trofes_Final_Fixed

# %%
# 1. Install Ultralytics
# !pip install ultralytics

# 2. Ekstrak dataset baru kamu
import zipfile
import os

# Pakai -q agar terminal tidak penuh dengan daftar ribuan foto
# !unzip -q "/content/drive/MyDrive/LastDataset_Trofes.v2-new.yolov8.zip" -d /content/dataset

print("✅ Dataset berhasil diekstrak ke /content/dataset")
# Out:
# ...
# replace /content/dataset/README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# ✅ Dataset berhasil diekstrak ke /content/dataset

# %%
# !find /content/dataset -name "*.cache" -type f -delete

# %%
import os
# Ambil satu file label secara acak
label_folder = '/content/dataset/train/labels'
file_label = os.listdir(label_folder)[0]

with open(os.path.join(label_folder, file_label), 'r') as f:
    print(f"File: {file_label}")
    print("--- ISI FILE (Angka di depan harus 0, 1, 2, dst) ---")
    print(f.read())
# Out:
# File: Image_25_jpg.rf.b8b2a3936bc77dedc21a72ca67f755d8.txt
# --- ISI FILE (Angka di depan harus 0, 1, 2, dst) ---
# 3 1 0.746091403125 0.9789789796875 0.767112425 0.99399399375 0.82416948125 0.99399399375 0.8421875 1 0.8421875 1 0.746091403125
# 3 0 0.8421875 0.9774774781250001 0.8421875 0.9789789796875 0.8061514640624999 0.9669669671875001 0.764109421875 0.8408408406250001 0.625971284375 0.783783784375 0.4818271390625 0.7267267265624999 0.4097550671875 0.6126126125 0.3436890015625 0.48648648593750005 0.31065596875 0.3483483484375 0.31065596875 0.2672672671875 0.32867398593749997 0.171171171875 0.37371903125 0.0570570578125 0.44579110312500003 0 0.5028481609375001 0 0.8421875

# %%
import yaml
yaml_path = '/content/dataset/data.yaml'
with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

config['path'] = '/content/dataset'
config['train'] = 'train/images'
config['val'] = 'valid/images'
config['test'] = 'test/images'

with open(yaml_path, 'w') as f:
    yaml.dump(config, f)
print("✅ Path data.yaml aman!")
# Out:
# ✅ Path data.yaml aman!

# %%
import shutil

# Folder backup
folder_backup = '/content/drive/MyDrive/Trofes_Project/Backup_Model_31'
if not os.path.exists(folder_backup):
    os.makedirs(folder_backup)

# Copy file best.pt lama
path_asal = '/content/drive/MyDrive/Trofes_Project/yolov8m_Detection_colab/weights/best.pt'
shutil.copy(path_asal, os.path.join(folder_backup, 'best_31_epoch_asli.pt'))

print("✅ Backup aman di folder Backup_Model_31")
# Out:
# ✅ Backup aman di folder Backup_Model_31

# %%
from ultralytics import YOLO

# 1. Load otak lama (Ingatan 31 epoch)
model = YOLO('/content/drive/MyDrive/Trofes_Project/yolov8m_Detection_colab/weights/best.pt')

# 2. Training 10 Epoch untuk 'Cuci Otak' Label
model.train(
    data='/content/dataset/data.yaml',
    epochs=10,
    imgsz=640,
    batch=16,
    project='/content/drive/MyDrive/Trofes_Project',
    name='yolov8m_Trofes_SANGAT_FIX',
    cache=False,    # Wajib False dulu biar dia baca label 0, 1, 2 yang baru kita cek tadi
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
